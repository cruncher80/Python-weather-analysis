# %% [markdown]
# # Weather Python Project
# ----
# See ReadMe for more information

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = '&units=imperial'

#to hold location info
inf = []

#loop through cities and get pertinent info
for index, city in enumerate(cities, start=1):
        print(f'Processing Record {index} | {city}')
        query_url = url + "appid=" + api_key + "&q=" + city + units
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        try:
            inf.append((city, weather_json['clouds']['all'], weather_json['sys']['country'], 
                   weather_json['dt'], weather_json['main']['humidity'], weather_json['coord']['lat'],
                   weather_json['coord']['lon'], weather_json['main']['temp_max'],
                   weather_json['wind']['speed']))
        except:
            print('City not found. Skipping...')
# Out:
# Processing Record 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 | nebolchi
# Processing Record 3 | castro
# Processing Record 4 | bredasdorp
# Processing Record 5 | sa kaeo
# Processing Record 6 | taolanaro
# City not found. Skipping...
# Processing Record 7 | kinanah
# City not found. Skipping...
# Processing Record 8 | clyde river
# Processing Record 9 | tasiilaq
# Processing Record 10 | mataura
# Processing Record 11 | amga
# Processing Record 12 | rikitea
# Processing Record 13 | ushuaia
# Processing Record 14 | sironko
# Processing Record 15 | albany
# Processing Record 16 | ponta do sol
# Processing Record 17 | danilovka
# Processing Record 18 | port alfred
# Processing Record 19 | ribeira grande
# Processing Record 20 | vaini
# Processing Record 21 | cape town
# Processing Record 22 | luganville
# Processing Record 23 | cabral
# Processing Record 24 | harker heights
# Processing Record 25 | kalach-na-donu
# Processing Record 26 | nikolskoye
# Processing Record 27 | shingu
# Processing Record 28 | axim
# Processing Record 29 | aksarayskiy
# Processing Record 30 | east london
# Processing Record 31 | mayumba
# Processing Record 32 | kyra
# Processing Record 33 | samarai
# Processing Record 34 | tuktoyaktuk
# Processing Record 35 | kapaa
# Processing Record 36 | atuona
# Processing Record 37 | punta arenas
# Processing Record 38 | khatanga
# Processing Record 39 | santa marta
# Processing Record 40 | pacific grove
# Processing Record 41 | dongsheng
# Processing Record 42 | safaqis
# City not found. Skipping...
# Processing Record 43 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 | jamestown
# Processing Record 45 | kuche
# City not found. Skipping...
# Processing Record 46 | kodiak
# Processing Record 47 | new norfolk
# Processing Record 48 | saint-francois
# Processing Record 49 | aripuana
# Processing Record 50 | najran
# Processing Record 51 | mar del plata
# Processing Record 52 | bethel
# Processing Record 53 | chokurdakh
# Processing Record 54 | hilo
# Processing Record 55 | chagda
# City not found. Skipping...
# Processing Record 56 | sitka
# Processing Record 57 | fleurus
# Processing Record 58 | hithadhoo
# Processing Record 59 | walvis bay
# Processing Record 60 | shimoda
# Processing Record 61 | busselton
# Processing Record 62 | fortuna
# Processing Record 63 | fujin
# Processing Record 64 | saint george
# Processing Record 65 | rio grande
# Processing Record 66 | alice town
# Processing Record 67 | kez
# Processing Record 68 | puerto ayora
# Processing Record 69 | saleaula
# City not found. Skipping...
# Processing Record 70 | camapua
# Processing Record 71 | longyearbyen
# Processing Record 72 | hasaki
# Processing Record 73 | victoria
# Processing Record 74 | lebu
# Processing Record 75 | vao
# Processing Record 76 | dikson
# Processing Record 77 | talnakh
# Processing Record 78 | avarua
# Processing Record 79 | hermanus
# Processing Record 80 | alofi
# Processing Record 81 | dodge city
# Processing Record 82 | shieli
# Processing Record 83 | bairnsdale
# Processing Record 84 | provideniya
# Processing Record 85 | fort nelson
# Processing Record 86 | almaznyy
# Processing Record 87 | cabo san lucas
# Processing Record 88 | semey
# Processing Record 89 | patacamaya
# Processing Record 90 | barrow
# Processing Record 91 | mwene-ditu
# Processing Record 92 | ancud
# Processing Record 93 | san-pedro
# Processing Record 94 | ocos
# Processing Record 95 | marsh harbour
# Processing Record 96 | mahon
# Processing Record 97 | tchollire
# Processing Record 98 | celestun
# Processing Record 99 | pimentel
# Processing Record 100 | arequipa
# Processing Record 101 | muhos
# Processing Record 102 | port lincoln
# Processing Record 103 | hualmay
# Processing Record 104 | carnarvon
# Processing Record 105 | makakilo city
# Processing Record 106 | broken hill
# Processing Record 107 | bluff
# Processing Record 108 | nalut
# Processing Record 109 | mahebourg
# Processing Record 110 | hobart
# Processing Record 111 | port blair
# Processing Record 112 | puerto cabezas
# Processing Record 113 | constitucion
# Processing Record 114 | fez
# Processing Record 115 | high rock
# Processing Record 116 | yarmouth
# Processing Record 117 | tongzi
# Processing Record 118 | mandalgovi
# Processing Record 119 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 120 | mosquera
# Processing Record 121 | chuy
# Processing Record 122 | kavaratti
# Processing Record 123 | kahramanmaras
# Processing Record 124 | port elizabeth
# Processing Record 125 | vila franca do campo
# Processing Record 126 | tangping
# Processing Record 127 | puerto del rosario
# Processing Record 128 | duobao
# Processing Record 129 | qaqortoq
# Processing Record 130 | butaritari
# Processing Record 131 | klaksvik
# Processing Record 132 | yaqui
# Processing Record 133 | bengkulu
# Processing Record 134 | geraldton
# Processing Record 135 | lagoa
# Processing Record 136 | manggar
# Processing Record 137 | sorong
# Processing Record 138 | atherton
# Processing Record 139 | pisco
# Processing Record 140 | nizhneyansk
# City not found. Skipping...
# Processing Record 141 | margate
# Processing Record 142 | biaora
# Processing Record 143 | grootfontein
# Processing Record 144 | coahuayana
# Processing Record 145 | tumannyy
# City not found. Skipping...
# Processing Record 146 | beringovskiy
# Processing Record 147 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 148 | madang
# Processing Record 149 | sola
# Processing Record 150 | belaya gora
# Processing Record 151 | brae
# Processing Record 152 | vardo
# Processing Record 153 | sioux lookout
# Processing Record 154 | kjollefjord
# Processing Record 155 | catuday
# Processing Record 156 | qaanaaq
# Processing Record 157 | christchurch
# Processing Record 158 | chiang khong
# Processing Record 159 | boyolangu
# Processing Record 160 | te kauwhata
# Processing Record 161 | syamzha
# Processing Record 162 | qasigiannguit
# Processing Record 163 | berberati
# Processing Record 164 | ahipara
# Processing Record 165 | sadowara
# City not found. Skipping...
# Processing Record 166 | koungou
# Processing Record 167 | gobabis
# Processing Record 168 | amahai
# Processing Record 169 | norman wells
# Processing Record 170 | tiksi
# Processing Record 171 | arona
# Processing Record 172 | galle
# Processing Record 173 | liverpool
# Processing Record 174 | kavieng
# Processing Record 175 | palmer
# Processing Record 176 | kutum
# Processing Record 177 | el balyana
# City not found. Skipping...
# Processing Record 178 | hambantota
# Processing Record 179 | gusau
# Processing Record 180 | san cristobal
# Processing Record 181 | yellowknife
# Processing Record 182 | dunedin
# Processing Record 183 | nanning
# Processing Record 184 | matagami
# Processing Record 185 | mys shmidta
# City not found. Skipping...
# Processing Record 186 | hofn
# Processing Record 187 | valleyview
# Processing Record 188 | berlevag
# Processing Record 189 | arraial do cabo
# Processing Record 190 | honiara
# Processing Record 191 | batagay-alyta
# Processing Record 192 | kieta
# Processing Record 193 | kosino
# Processing Record 194 | barentsburg
# City not found. Skipping...
# Processing Record 195 | mana
# Processing Record 196 | galveston
# Processing Record 197 | lompoc
# Processing Record 198 | kysyl-syr
# Processing Record 199 | attawapiskat
# City not found. Skipping...
# Processing Record 200 | isangel
# Processing Record 201 | sao filipe
# Processing Record 202 | viligili
# City not found. Skipping...
# Processing Record 203 | campeche
# Processing Record 204 | bilma
# Processing Record 205 | buala
# Processing Record 206 | vestmannaeyjar
# Processing Record 207 | sayyan
# Processing Record 208 | sambava
# Processing Record 209 | leningradskiy
# Processing Record 210 | chongwe
# Processing Record 211 | iqaluit
# Processing Record 212 | tshikapa
# Processing Record 213 | cherskiy
# Processing Record 214 | port hardy
# Processing Record 215 | naryan-mar
# Processing Record 216 | zhanaozen
# Processing Record 217 | kudahuvadhoo
# Processing Record 218 | piterka
# Processing Record 219 | kushmurun
# Processing Record 220 | praia da vitoria
# Processing Record 221 | muros
# Processing Record 222 | pevek
# Processing Record 223 | olafsvik
# Processing Record 224 | lac du bonnet
# Processing Record 225 | markova
# Processing Record 226 | babu
# Processing Record 227 | louisbourg
# City not found. Skipping...
# Processing Record 228 | kahului
# Processing Record 229 | vanavara
# Processing Record 230 | karratha
# Processing Record 231 | iskateley
# Processing Record 232 | nguiu
# City not found. Skipping...
# Processing Record 233 | corrales
# Processing Record 234 | preobrazheniye
# Processing Record 235 | havre-saint-pierre
# Processing Record 236 | ugoofaaru
# Processing Record 237 | redlands
# Processing Record 238 | samalaeulu
# City not found. Skipping...
# Processing Record 239 | fukue
# Processing Record 240 | puerto carreno
# Processing Record 241 | koutsouras
# Processing Record 242 | eureka
# Processing Record 243 | kazalinsk
# City not found. Skipping...
# Processing Record 244 | maniitsoq
# Processing Record 245 | sosua
# Processing Record 246 | saquarema
# Processing Record 247 | xichang
# Processing Record 248 | ulaangom
# Processing Record 249 | ranong
# Processing Record 250 | chapais
# Processing Record 251 | ormara
# Processing Record 252 | kaputa
# Processing Record 253 | pirovskoye
# Processing Record 254 | aklavik
# Processing Record 255 | valley city
# Processing Record 256 | krasnoselkup
# Processing Record 257 | asau
# Processing Record 258 | lazi
# Processing Record 259 | bubaque
# Processing Record 260 | dolzhanskaya
# Processing Record 261 | kirakira
# Processing Record 262 | nakasongola
# Processing Record 263 | namibe
# Processing Record 264 | dolbeau
# City not found. Skipping...
# Processing Record 265 | bambanglipuro
# Processing Record 266 | devyatka
# City not found. Skipping...
# Processing Record 267 | paamiut
# Processing Record 268 | altamira
# Processing Record 269 | mooi river
# City not found. Skipping...
# Processing Record 270 | moche
# Processing Record 271 | katsuura
# Processing Record 272 | nicoya
# Processing Record 273 | rocha
# Processing Record 274 | codrington
# Processing Record 275 | temecula
# Processing Record 276 | torbay
# Processing Record 277 | powell river
# Processing Record 278 | ostrovnoy
# Processing Record 279 | mount isa
# Processing Record 280 | mumbwa
# Processing Record 281 | anloga
# Processing Record 282 | college
# Processing Record 283 | coruripe
# Processing Record 284 | kruisfontein
# Processing Record 285 | rapid valley
# Processing Record 286 | labuhan
# Processing Record 287 | mapiri
# Processing Record 288 | araouane
# Processing Record 289 | umzimvubu
# City not found. Skipping...
# Processing Record 290 | mount gambier
# Processing Record 291 | marcona
# City not found. Skipping...
# Processing Record 292 | san patricio
# Processing Record 293 | saint austell
# Processing Record 294 | adoni
# Processing Record 295 | eastbourne
# Processing Record 296 | esperance
# Processing Record 297 | acarau
# Processing Record 298 | dingle
# Processing Record 299 | suntar
# Processing Record 300 | praia
# Processing Record 301 | dinagat
# Processing Record 302 | alyangula
# Processing Record 303 | namatanai
# Processing Record 304 | avera
# Processing Record 305 | kyzyl-suu
# Processing Record 306 | nakambala
# Processing Record 307 | misratah
# Processing Record 308 | grindavik
# Processing Record 309 | bouar
# Processing Record 310 | tres arroyos
# Processing Record 311 | eidsvoll
# Processing Record 312 | wenling
# Processing Record 313 | georgetown
# Processing Record 314 | santa cruz del sur
# Processing Record 315 | portland
# Processing Record 316 | port macquarie
# Processing Record 317 | kpandae
# Processing Record 318 | mogadishu
# Processing Record 319 | sao gabriel da cachoeira
# Processing Record 320 | itarema
# Processing Record 321 | omboue
# Processing Record 322 | salalah
# Processing Record 323 | eydhafushi
# Processing Record 324 | galbshtadt
# Processing Record 325 | ola
# Processing Record 326 | bambous virieux
# Processing Record 327 | jiaojiang
# Processing Record 328 | nenjiang
# Processing Record 329 | bonthe
# Processing Record 330 | ko samui
# Processing Record 331 | shubarkuduk
# Processing Record 332 | grand gaube
# Processing Record 333 | tsihombe
# City not found. Skipping...
# Processing Record 334 | kavakli
# Processing Record 335 | cockburn town
# Processing Record 336 | saint-philippe
# Processing Record 337 | samusu
# City not found. Skipping...
# Processing Record 338 | rawson
# Processing Record 339 | thompson
# Processing Record 340 | yar-sale
# Processing Record 341 | kabo
# Processing Record 342 | weyburn
# Processing Record 343 | plouzane
# Processing Record 344 | havelock
# Processing Record 345 | huarmey
# Processing Record 346 | nouadhibou
# Processing Record 347 | maghama
# City not found. Skipping...
# Processing Record 348 | cap-aux-meules
# Processing Record 349 | airai
# Processing Record 350 | wels
# Processing Record 351 | santa rosa
# Processing Record 352 | daru
# Processing Record 353 | yambio
# Processing Record 354 | vostok
# Processing Record 355 | hobyo
# Processing Record 356 | leh
# Processing Record 357 | posse
# Processing Record 358 | mahajanga
# Processing Record 359 | inuvik
# Processing Record 360 | plettenberg bay
# Processing Record 361 | copiapo
# Processing Record 362 | otane
# Processing Record 363 | sapa
# Processing Record 364 | wilmington
# Processing Record 365 | fort morgan
# Processing Record 366 | sabang
# Processing Record 367 | naze
# Processing Record 368 | hay river
# Processing Record 369 | half moon bay
# Processing Record 370 | assiniboia
# Processing Record 371 | san quintin
# Processing Record 372 | namie
# Processing Record 373 | aksu
# Processing Record 374 | yemtsa
# Processing Record 375 | tiznit
# Processing Record 376 | mehkar
# Processing Record 377 | nome
# Processing Record 378 | araguacu
# Processing Record 379 | fevralsk
# City not found. Skipping...
# Processing Record 380 | baoshan
# Processing Record 381 | gidole
# Processing Record 382 | tsienyane
# City not found. Skipping...
# Processing Record 383 | afua
# Processing Record 384 | eldikan
# City not found. Skipping...
# Processing Record 385 | boguchany
# Processing Record 386 | kangaatsiaq
# Processing Record 387 | upernavik
# Processing Record 388 | yaya
# Processing Record 389 | saskylakh
# Processing Record 390 | swan river
# Processing Record 391 | puerto escondido
# Processing Record 392 | hihifo
# City not found. Skipping...
# Processing Record 393 | platteville
# Processing Record 394 | gboko
# Processing Record 395 | guanica
# Processing Record 396 | japura
# Processing Record 397 | vila velha
# Processing Record 398 | rafai
# Processing Record 399 | touros
# Processing Record 400 | matara
# Processing Record 401 | medicine hat
# Processing Record 402 | le port
# Processing Record 403 | tuy hoa
# Processing Record 404 | port-cartier
# Processing Record 405 | husavik
# Processing Record 406 | guicheng
# City not found. Skipping...
# Processing Record 407 | liku
# Processing Record 408 | pekalongan
# Processing Record 409 | la asuncion
# Processing Record 410 | chihuahua
# Processing Record 411 | palabuhanratu
# City not found. Skipping...
# Processing Record 412 | viedma
# Processing Record 413 | roald
# Processing Record 414 | nanortalik
# Processing Record 415 | kaitangata
# Processing Record 416 | laguna
# Processing Record 417 | gweta
# Processing Record 418 | kaliua
# Processing Record 419 | bilibino
# Processing Record 420 | santa cruz
# Processing Record 421 | ende
# Processing Record 422 | kang
# Processing Record 423 | livingston
# Processing Record 424 | allahabad
# Processing Record 425 | jiehu
# Processing Record 426 | khor
# Processing Record 427 | kalmunai
# Processing Record 428 | mundo nuevo
# Processing Record 429 | san francisco
# Processing Record 430 | turukhansk
# Processing Record 431 | puerto madryn
# Processing Record 432 | kafanchan
# Processing Record 433 | arklow
# Processing Record 434 | koyilandi
# City not found. Skipping...
# Processing Record 435 | yumen
# Processing Record 436 | bacolod
# Processing Record 437 | abu kamal
# Processing Record 438 | aniva
# Processing Record 439 | baruun-urt
# Processing Record 440 | slave lake
# Processing Record 441 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 442 | mabaruma
# Processing Record 443 | sampit
# Processing Record 444 | kralendijk
# Processing Record 445 | amderma
# City not found. Skipping...
# Processing Record 446 | santa vitoria do palmar
# Processing Record 447 | marienburg
# Processing Record 448 | jalu
# Processing Record 449 | bonavista
# Processing Record 450 | ahuimanu
# Processing Record 451 | billings
# Processing Record 452 | madaras
# Processing Record 453 | harper
# Processing Record 454 | ambanja
# Processing Record 455 | watrous
# Processing Record 456 | erzin
# Processing Record 457 | acapulco
# Processing Record 458 | coquimbo
# Processing Record 459 | udachnyy
# Processing Record 460 | cayenne
# Processing Record 461 | lima
# Processing Record 462 | smithers
# Processing Record 463 | whitecourt
# Processing Record 464 | togur
# Processing Record 465 | ambilobe
# Processing Record 466 | lagos
# Processing Record 467 | severo-kurilsk
# Processing Record 468 | sao joao da barra
# Processing Record 469 | tupik
# Processing Record 470 | novonukutskiy
# Processing Record 471 | skalistyy
# City not found. Skipping...
# Processing Record 472 | mahina
# Processing Record 473 | qiongshan
# Processing Record 474 | funtua
# Processing Record 475 | vaitupu
# City not found. Skipping...
# Processing Record 476 | wellington
# Processing Record 477 | forset
# City not found. Skipping...
# Processing Record 478 | whitefish bay
# Processing Record 479 | riyadh
# Processing Record 480 | sabha
# Processing Record 481 | cidreira
# Processing Record 482 | tura
# Processing Record 483 | road town
# Processing Record 484 | khonuu
# City not found. Skipping...
# Processing Record 485 | boden
# Processing Record 486 | zyryanka
# Processing Record 487 | tabuk
# Processing Record 488 | turan
# Processing Record 489 | ouahigouya
# Processing Record 490 | necochea
# Processing Record 491 | lavrentiya
# Processing Record 492 | northam
# Processing Record 493 | nikel
# Processing Record 494 | port shepstone
# Processing Record 495 | le havre
# Processing Record 496 | taybad
# Processing Record 497 | phangnga
# Processing Record 498 | pandan
# Processing Record 499 | anadyr
# Processing Record 500 | mujiayingzi
# Processing Record 501 | zhigansk
# Processing Record 502 | gornopravdinsk
# Processing Record 503 | deputatskiy
# Processing Record 504 | amot
# Processing Record 505 | port antonio
# Processing Record 506 | qunduz
# Processing Record 507 | zhongshu
# Processing Record 508 | pangkalanbuun
# Processing Record 509 | biak
# Processing Record 510 | tamandare
# Processing Record 511 | pangoa
# Processing Record 512 | okhotsk
# Processing Record 513 | cabedelo
# Processing Record 514 | sawakin
# Processing Record 515 | bastia
# Processing Record 516 | were ilu
# Processing Record 517 | trairi
# Processing Record 518 | malwan
# City not found. Skipping...
# Processing Record 519 | meulaboh
# Processing Record 520 | byron bay
# Processing Record 521 | luderitz
# Processing Record 522 | grand river south east
# City not found. Skipping...
# Processing Record 523 | guerrero negro
# Processing Record 524 | kongolo
# Processing Record 525 | saumur
# Processing Record 526 | dukat
# Processing Record 527 | baker city
# Processing Record 528 | peniche
# Processing Record 529 | aitape
# Processing Record 530 | ayagoz
# Processing Record 531 | nadym
# Processing Record 532 | awjilah
# Processing Record 533 | nizwa
# Processing Record 534 | dawei
# Processing Record 535 | noumea
# Processing Record 536 | saint-leu
# Processing Record 537 | zolotinka
# City not found. Skipping...
# Processing Record 538 | vallenar
# Processing Record 539 | ballina
# Processing Record 540 | adrar
# Processing Record 541 | aromashevo
# Processing Record 542 | lorengau
# Processing Record 543 | ust-kalmanka
# Processing Record 544 | rio gallegos
# Processing Record 545 | shar
# Processing Record 546 | usinsk
# Processing Record 547 | kirkwall
# Processing Record 548 | doka
# Processing Record 549 | bandarbeyla
# Processing Record 550 | svetlogorsk
# Processing Record 551 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 552 | hamilton
# Processing Record 553 | angra
# City not found. Skipping...
# Processing Record 554 | conceicao do araguaia
# Processing Record 555 | lasa
# Processing Record 556 | sarkand
# Processing Record 557 | duku
# Processing Record 558 | sisimiut
# Processing Record 559 | port hawkesbury
# Processing Record 560 | hami
# Processing Record 561 | gizo
# Processing Record 562 | innisfail
# Processing Record 563 | old town
# Processing Record 564 | santa rosalia
# Processing Record 565 | noyabrsk
# Processing Record 566 | freital
# Processing Record 567 | umm lajj
# Processing Record 568 | itupiranga
# Processing Record 569 | kununurra
# Processing Record 570 | itoman
# Processing Record 571 | salta
# Processing Record 572 | gat
# Processing Record 573 | laukaa
# Processing Record 574 | yatou
# Processing Record 575 | te anau
# Processing Record 576 | uvalde
# Processing Record 577 | darnah
# Processing Record 578 | souillac
# Processing Record 579 | bouca
# Processing Record 580 | faanui
# Processing Record 581 | dhupgari
# Processing Record 582 | waqqas
# Processing Record 583 | bom jesus
# Processing Record 584 | preston
# Processing Record 585 | oussouye
# Processing Record 586 | tabiauea
# City not found. Skipping...
# Processing Record 587 | sinnamary
# Processing Record 588 | knysna
# Processing Record 589 | mugur-aksy
# Processing Record 590 | soyo
# Processing Record 591 | saint-pierre
# Processing Record 592 | faya
# Processing Record 593 | waipawa
# Processing Record 594 | deoli
# Processing Record 595 | saldanha
# Processing Record 596 | yanchukan
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create df from tuples
location_df = pd.DataFrame(inf, columns=('City', 'Cloudiness', 'Country', 
                                         'Date', 'Humidity', 'Lat', 'Lng', 
                                         'Max Temp(F)', 'Wind Speed(mph)'))
location_df.to_csv('raw_loc_data.csv')
location_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     nebolchi          49      RU  1581013593        84  59.12   33.35
# 1       castro          49      BR  1581013460        88 -24.79  -50.01
# 2   bredasdorp          99      ZA  1581013512        68 -34.53   20.04
# 3      sa kaeo          25      TH  1581013594        75  13.81  102.07
# 4  clyde river           1      CA  1581013533        67  70.47  -68.59
#
#    Max Temp(F)  Wind Speed(mph)
# 0        20.64            18.01
# 1        75.72             4.85
# 2        66.20            16.11
# 3        75.24             0.81
# 4       -22.00            13.87

# %%
location_df.count()
# Out:
# City               546
# Cloudiness         546
# Country            546
# Date               546
# Humidity           546
# Lat                546
# Lng                546
# Max Temp(F)        546
# Wind Speed(mph)    546
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#This provides a scatter plot that maps our cities. we can clearly see that we got a sample from all across the globe
plt.scatter(location_df['Lng'], location_df['Lat'], edgecolor='k')
plt.grid(True)
plt.title('City Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#save and then show chart
plt.savefig('mappedcities.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#set up scatter plot
plt.scatter(location_df['Lat'], location_df['Max Temp(F)'], edgecolor='k')
plt.grid(True)
plt.title('City Latitude vs Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

#save and then show chart
plt.savefig('latitudevstemperature.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#set up chart
plt.scatter(location_df['Lat'], location_df['Humidity'], edgecolor='k')
plt.grid(True)
plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

#save and then show chart
plt.savefig('latitudevshumidity.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#set up chart
plt.scatter(location_df['Lat'], location_df['Cloudiness'], edgecolor='k')
plt.grid(True)
plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#save and then show chart
plt.savefig('latitudevscloudiness.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#set up chart
plt.scatter(location_df['Lat'], location_df['Wind Speed(mph)'], edgecolor='k')
plt.grid(True)
plt.title('City Latitude vs Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')

#save and then show chart
plt.savefig('latitudevswindspeed.png')
plt.show()

# %%
#set up chart
plt.scatter(location_df['Lng'], location_df['Wind Speed(mph)'], edgecolor='k')
plt.grid(True)
plt.title('City Longitude vs Wind Speed (mph)')
plt.xlabel('Longitude')
plt.ylabel('Wind Speed(mph)')

# #save and then show chart
plt.savefig('longitudevswindspeed.png')
plt.show()

# %% [markdown]
# # Conclusions:
#     1) As expected, there is a clear correlation between max temperature and city latitude
#     2) There is no clear correlation between wind speed and either latitude or longitude.
#     3) There is no clear correlation between cloudiness and city latitude; however, the shape of the scatter plot does seem to indicate that this is based more on an estimation or possibly a range. The plots are grouped at certain points on the scale: 0, 20, 40, 75, and 100
